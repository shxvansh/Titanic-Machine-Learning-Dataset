# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train_data_raw = pd.read_csv('train.csv')
test_data_raw = pd.read_csv('test.csv')

# %%
# train_data_raw.shape

# %%
# test_data_raw.shape

# %%
test_data_raw['Survived'] = 0

# %%
df = pd.concat([train_data_raw,test_data_raw],axis=0)

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         0       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# df.describe().transpose()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = df.set_index('PassengerId')

# %%
df.drop('Name',axis=1,inplace=True)

# %%
sex_dummy = pd.get_dummies(df['Sex'])

# %%
df = pd.concat([df,sex_dummy],axis=1)

# %%
df.drop('Sex',axis=1,inplace=True)

# %%
df.drop('Ticket',axis=1,inplace=True)

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare Embarked  female  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500        S   False
# 2                   1       1  38.0      1      0  71.2833        C    True
# 3                   1       3  26.0      0      0   7.9250        S    True
# 4                   1       1  35.0      1      0  53.1000        S    True
# 5                   0       3  35.0      0      0   8.0500        S   False
#
#               male
# PassengerId
# 1             True
# 2            False
# 3            False
# 4            False
# 5             True

# %%
embarked_dummies = pd.get_dummies(df['Embarked'])

# %%
df = pd.concat([df,embarked_dummies],axis=1)

# %%
df.drop('Embarked',axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# female      0
# male        0
# C           0
# Q           0
# S           0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  female   male  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500   False   True
# 2                   1       1  38.0      1      0  71.2833    True  False
# 3                   1       3  26.0      0      0   7.9250    True  False
# 4                   1       1  35.0      1      0  53.1000    True  False
# 5                   0       3  35.0      0      0   8.0500   False   True
#
#                  C      Q      S
# PassengerId
# 1            False  False   True
# 2             True  False  False
# 3            False  False   True
# 4            False  False   True
# 5            False  False   True

# %%
df['Fare'] = df['Fare'].fillna(df['Fare'].mean())

# %%
# sns.pairplot(df)

# %%
df.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  female   male  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500   False   True
# 2                   1       1  38.0      1      0  71.2833    True  False
# 3                   1       3  26.0      0      0   7.9250    True  False
# 4                   1       1  35.0      1      0  53.1000    True  False
# 5                   0       3  35.0      0      0   8.0500   False   True
#
#                  C      Q      S
# PassengerId
# 1            False  False   True
# 2             True  False  False
# 3            False  False   True
# 4            False  False   True
# 5            False  False   True

# %%
train_data_raw.shape
# Out:
# (891, 12)

# %%
Pclass_dummy = pd.get_dummies(df['Pclass'])

# %%
df = pd.concat([df,Pclass_dummy],axis=1)

# %%
df.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  female   male  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500   False   True
# 2                   1       1  38.0      1      0  71.2833    True  False
# 3                   1       3  26.0      0      0   7.9250    True  False
# 4                   1       1  35.0      1      0  53.1000    True  False
# 5                   0       3  35.0      0      0   8.0500   False   True
#
#                  C      Q      S      1      2      3
# PassengerId
# 1            False  False   True  False  False   True
# 2             True  False  False   True  False  False
# 3            False  False   True  False  False   True
# 4            False  False   True   True  False  False
# 5            False  False   True  False  False   True

# %%
df.drop([1,2,3],axis=1,inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  female   male  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500   False   True
# 2                   1       1  38.0      1      0  71.2833    True  False
# 3                   1       3  26.0      0      0   7.9250    True  False
# 4                   1       1  35.0      1      0  53.1000    True  False
# 5                   0       3  35.0      0      0   8.0500   False   True
#
#                  C      Q      S
# PassengerId
# 1            False  False   True
# 2             True  False  False
# 3            False  False   True
# 4            False  False   True
# 5            False  False   True

# %%
training_data = df[:len(train_data_raw)]
testing_data = df[len(train_data_raw):]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
testing_data.drop('Survived',axis=1,inplace=True)

# %%
X = training_data.drop('Survived',axis=1)
y = training_data['Survived']

# %%
y.shape
# Out:
# (891,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
# y_train = np.reshape(y_train,(-1,1))
# y_test = np.reshape(y_test,(-1,1))

# %%
df.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  female   male  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500   False   True
# 2                   1       1  38.0      1      0  71.2833    True  False
# 3                   1       3  26.0      0      0   7.9250    True  False
# 4                   1       1  35.0      1      0  53.1000    True  False
# 5                   0       3  35.0      0      0   8.0500   False   True
#
#                  C      Q      S
# PassengerId
# 1            False  False   True
# 2             True  False  False
# 3            False  False   True
# 4            False  False   True
# 5            False  False   True

# %%
model1 = LogisticRegression()
model2 = DecisionTreeClassifier()
model3 = RandomForestClassifier()
model4 = XGBClassifier(max_depth=3,learning_rate=0.45,n_estimators=30)
model5 = LGBMClassifier(num_leaves=20,learning_rate=0.45,n_estimators=30)

# %%
model5.fit(X_train,y_train)
pred5 = model5.predict(X_test)
accuracy_score(y_test,pred5)
# Out:
# [LightGBM] [Info] Number of positive: 264, number of negative: 448
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203
# [LightGBM] [Info] Number of data points in the train set: 712, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.370787 -> initscore=-0.528844
# [LightGBM] [Info] Start training from score -0.528844
# 0.8435754189944135

# %%
model4.fit(X_train_scaled,y_train)
pred4 = model4.predict(X_test_scaled)
accuracy_score(y_test,pred4)
# Out:
# 0.8156424581005587

# %%
model1.fit(X_train,y_train)
pred1 = model1.predict(X_test)
accuracy_score(y_test,pred1)
# Out:
# 0.7597765363128491

# %%
model2.fit(X_train,y_train)
pred2 = model2.predict(X_test)
accuracy_score(y_test,pred2)
# Out:
# 0.7821229050279329

# %%
model3.fit(X_train,y_train)
pred3 = model3.predict(X_test)
accuracy_score(y_test,pred3)
# Out:
# 0.8044692737430168

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
predictions = model5.predict(testing_data)

final = pd.DataFrame()
final['PassengerId'] = testing_data.index
final['Survived'] = predictions

# %%
final.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
final.to_csv('submission.csv',index=False)
